# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\HP\Desktop\datasets\DataScience_salaries_2024.csv")

# %%
data
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14838 entries, 0 to 14837
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14838 non-null  int64
#  1   experience_level    14838 non-null  object
#  2   employment_type     14838 non-null  object
#  3   job_title           14838 non-null  object
#  4   salary              14838 non-null  int64
#  5   salary_currency     14838 non-null  object
#  6   salary_in_usd       14838 non-null  int64
#  7   employee_residence  14838 non-null  object
#  8   remote_ratio        14838 non-null  int64
#  9   company_location    14838 non-null  object
#  10  company_size        14838 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  14838.000000  1.483800e+04   14838.000000  14838.000000
# mean    2023.138900  1.650227e+05  149874.718763     32.760480
# std        0.700799  3.562354e+05   69009.181349     46.488278
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.021000e+05  102000.000000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.875000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %%
data.nunique()
# Out:
# work_year                5
# experience_level         4
# employment_type          4
# job_title              153
# salary                2363
# salary_currency         23
# salary_in_usd         2730
# employee_residence      88
# remote_ratio             3
# company_location        77
# company_size             3
# dtype: int64

# %%
data.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
data['company_size'].unique()
# Out:
# array(['L', 'S', 'M'], dtype=object)

# %%
data.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
sns.boxplot(data['salary'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['salary_in_usd'])
# Out:
# <Axes: >

# %%
Q1=data.salary.quantile(0.25)
Q3=data.salary.quantile(0.75)
IQR=Q3-Q1

# %%
Q1,Q3
# Out:
# (102100.0, 187500.0)

# %%
IQR
# Out:
# 85400.0

# %%
lower_limit=Q1- 1.5*IQR
upper_limit=Q3+ 1.5*IQR

# %%
lower_limit,upper_limit
# Out:
# (-26000.0, 315600.0)

# %%
data[(data.salary<lower_limit)|(data.salary>upper_limit)]
# Out:
#      work_year experience_level employment_type  \
# 0         2021               MI              FT
# 1         2021               MI              FT
# 2         2020               MI              FT
# 3         2021               MI              FT
# 4         2022               SE              FT
# ..         ...              ...             ...
# 322       2023               SE              FT
# 323       2023               SE              FT
# 324       2023               SE              FT
# 325       2023               SE              FT
# 326       2023               SE              FT
#
#                           job_title    salary salary_currency  salary_in_usd  \
# 0                    Data Scientist  30400000             CLP          40038
# 1                   BI Data Analyst  11000000             HUF          36259
# 2                    Data Scientist  11000000             HUF          35735
# ...

# %%
data
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %%
data_no_outlier=data[(data.salary>lower_limit)&(data.salary<upper_limit)]

# %%
data_no_outlier
# Out:
#        work_year experience_level employment_type  \
# 327         2023               SE              FT
# 328         2024               SE              FT
# 329         2022               SE              FT
# 330         2024               SE              FT
# 331         2023               EX              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title  salary salary_currency  salary_in_usd  \
# 327          Machine Learning Engineer  315300             USD         315300
# 328          Machine Learning Engineer  315000             USD         315000
# 329                      Data Engineer  315000             USD         315000
# ...

# %%
sns.boxplot(data_no_outlier)
# Out:
# <Axes: >

# %%
data
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %%
sns.countplot(x=data['experience_level'])

# %%
sns.countplot(x=data['company_size'])
# Out:
# <Axes: xlabel='company_size', ylabel='count'>
